# %% [markdown]
# #エラーハンドリングについて

# %%
X = 1
Y = 0

# %%
#0で割っているので、エラーが起きてしまう
X / Y
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 #0で割っているので、エラーが起きてしまう
# ----> 2 X / Y
#
# ZeroDivisionError: division by zero

# %%
try:
    result = X/Y
except ZeroDivisionError as e:
    result = None
    print("エラーが発生しました",e)
    print("0で割ることができません。結果はnoteに設定しました")

print("結果",None)
# Out:
# エラーが発生しました division by zero
# 0で割ることができません。結果はnoteに設定しました
# 結果 None

# %%
try:
    result = X/Z
except ZeroDivisionError as e:
    result = None
    print("エラーが発生しました",e)
    print("0で割ることができません。結果はnoteに設定しました")
except NameError as e:
    result = None
    print("エラーが発生しました",e)
    print("0で割ることができません。結果はnoteに設定しました")
# Out:
# エラーが発生しました name 'Z' is not defined
# 0で割ることができません。結果はnoteに設定しました

# %%
Z = 3

try:
    result = X/Z
except ZeroDivisionError as e:
    result = None
    print("エラーが発生しました",e)
    print("0で割ることができません。結果はnoteに設定しました")
except NameError as e:
    result = None
    print("エラーが発生しました",e)
    print("0で割ることができません。結果はnoteに設定しました")
else:
    #tryブロック内でエラーが発生しなかった場合に実行される
    print("エラーが発生しませんでした。")
finally:
    #tryブロック内でのエラーの発生の有無に関わらず実行される
    print("計算処理が完了しました")
print("結果",result)
# Out:
# エラーが発生しませんでした。
# 計算処理が完了しました
# 結果 0.3333333333333333

# %%
x = 1
y = 0
Z = 3

try:
    result = x/y
except Exception as e:
    result = None
    print("エラーが")

# %% [markdown]
# WEBスクレインピングでのエラー処理

# %%
import requests

# %%
url = 'https://www.musashino-u.ac.jp/invalid-page'
respone = requests.get{url}
print()

# %%
url = 'https://www.musashino-u.ac.jp/invalid-page'

try:
